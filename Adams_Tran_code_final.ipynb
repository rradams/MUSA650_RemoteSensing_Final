# %% [markdown]
# <a href="https://colab.research.google.com/github/rradams/MUSA650_RemoteSensing_Final/blob/main/Adams_Tran_code_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Classifying Urban Land in Indonesia Using Satellite Imagery**
#
# Rebekah Adams and Tiffany M. Tran
#
# Department of City and Regional Planning, University of Pennsylvania
#
# MUSA 6500 Geospatial Machine Learning in Remote Sensing
#
# Dr. Guray Erus
#
# April 2023

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import math
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import RMSprop # optimizer
import keras
import tensorflow as tf
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# # Set up functions

# %%
# Create function to plot confusion matrix
def plot_cm(model, test_data, title):
  predict_x = np.round(model.predict(test_data))
  cm = confusion_matrix(Y_test, predict_x)
  disp = ConfusionMatrixDisplay(confusion_matrix= cm,
                                display_labels=categories)
  
  return(
      disp.plot(),
      disp.ax_.set_title(f"{title}")
  )

# %%
# Create function to plot ROC curve - how to make less angular?
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(model, test_set):
  predict_x=model.predict(test_set) # predictions with probabilities for each class, i.e. the best guess

  # Compute fpr, tpr, thresholds and roc auc
  fpr, tpr, thresholds = roc_curve(Y_test, predict_x)
  roc_auc = auc(fpr, tpr)

  # Plot ROC curve
  return(
      plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc),
      plt.plot([0, 1], [0, 1], 'k--'),  # random predictions curve
      plt.xlim([0.0, 1.0]),
      plt.ylim([0.0, 1.0]),
      plt.xlabel('False Positive Rate or (1 - Specifity)'),
      plt.ylabel('True Positive Rate or (Sensitivity)'),
      plt.title('Receiver Operating Characteristic'),
      plt.legend(loc="lower right")
  )

# %%
  # Plot images of False Positives - images that were predicted as Urban, but were actually Not Urban
  # This could help us identify areas of urban expansion

from mpl_toolkits.axes_grid1 import ImageGrid

def plot_false_positives(model, test_set):

    predict_x = np.round(model.predict(test_set))
    wrong_classifications = predict_x - Y_test # predicted classes - actual classes # classes_x
    wrong_classifications_index = np.array(np.where(wrong_classifications != 0))[:1,:] # index of where predictions were wrong
    wrong_predictions = predict_x[wrong_classifications_index] # use index to find wrong predictions # classes_x
    wrong_y_true = Y_test[wrong_classifications_index] # use index to find correct labels of wrong predictions
    wrong_x_true = X_test[wrong_classifications_index] # use index to find pixels of incorrectly-predicted images

    # Identify False Positive - true Not Urban, predicted as Urban
    FP_index = np.where(wrong_y_true == 0) # find labels Not Urban areas, i.e. the false positives (Non-Urban labelled as 0)
    FP_labels = wrong_y_true[FP_index]
    FP_images = wrong_x_true[FP_index]

    # Select random sample of images from false positive results
    index_list = []

    for i in range(0,4):
      random_index = np.random.choice(FP_labels.shape[0])
      index_list.append(random_index)

    # Use random index to select four random images
    image_1 = FP_images[index_list[0]].reshape(64,64,3)
    image_2 = FP_images[index_list[1]].reshape(64,64,3)
    image_3 = FP_images[index_list[2]].reshape(64,64,3)
    image_4 = FP_images[index_list[3]].reshape(64,64,3)

    # Plot
    fig = plt.figure() #figsize=(4., 4.))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                    nrows_ncols=(2, 2),  # creates 2x2 grid of axes
                    axes_pad=0.1,  # pad between axes in inch.
                    )

    for ax, im in zip(grid, [image_1, image_2, image_3, image_4]):
        # Iterating over the grid returns the Axes.
        ax.imshow(im)

    return(grid.axes_all[1].set_title("Examples of False Positive Classifications - Predicted as Urban, but are officially not urban"))

# %%
# Function to plot accuracy and loss for each model
def plot_accuracy_and_loss(model_history):
  return(
    plt.plot(model_history.history['accuracy']),
    plt.plot(model_history.history['val_accuracy']),
    plt.title('model accuracy'),
    plt.ylabel('accuracy'),
    plt.xlabel('epoch'),
    plt.legend(['train', 'test'], loc='upper left'),
    plt.show(),

    plt.plot(model_history.history['loss']),
    plt.plot(model_history.history['val_loss']),
    plt.title('model loss'),
    plt.ylabel('loss'),
    plt.xlabel('epoch'),
    plt.legend(['train', 'test'], loc='upper left'),
    plt.show(),
  )

# %% [markdown]
# # Import images

# %%
# import images

import os
import skimage
from skimage import io
import numpy as np
from glob import glob
from pathlib import Path

raw_labels =[]
raw_images = []
raw_label_names = []
here = Path(os.getcwd())

for idx, directory in enumerate(sorted((here / "drive/MyDrive/MUSA650_RemoteSensing_Final/data/").glob("*"))):  # keep this line for running on colab
#for idx, directory in enumerate(sorted((here / "./data/cirebon").glob("*"))):  # Keep this line for running locally
    for img_path in directory.glob("*.jpg"):
        raw_labels.append(idx)
        raw_label_names.append(directory)
        raw_images.append(io.imread(img_path))
        
# convert to numpy arrays
images = np.array(raw_images)
images = images[:, :64, :64, :3] # trim extra pixel and alpha channel
labels = np.array(raw_labels)
label_names = np.array(raw_label_names)

# %%
# view label names
label_names
# Out:
# array([PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        ...,
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban')],
#       dtype=object)

# %%
# confirm images are correctly labeled (not_urban = 0, urban = 1)
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
# Confrim the range of values in the dataset - yes, they are between 0 and 255
print("Max pixel value is: ", images.max())
print("Min pixel value is: ", images.min())
# Out:
# Max pixel value is:  255
# Min pixel value is:  0

# %%
# Draw out just the urban images
urban_labels_index = np.where(labels == 1)
urban_labels = labels[urban_labels_index]
urban_images = images[urban_labels_index]

# %%
# Draw out just the non-urban images
non_urban_labels_index = np.where(labels == 0)
non_urban_labels = labels[non_urban_labels_index]
non_urban_images = images[non_urban_labels_index]

# Generate a random selection of non-urban images - the same number as urban images.
NU_labels_subset = []
NU_images_subset = []

for i in range(0, urban_labels.shape[0]):
  random_index_for_subset = np.random.choice(non_urban_labels.shape[0])
  subset_label = non_urban_labels[random_index_for_subset]
  subset_image = non_urban_images[random_index_for_subset]
  NU_labels_subset.append(subset_label)
  NU_images_subset.append(subset_image)

# Convert to numpy arrays
non_urban_images = np.array(NU_images_subset)
non_urban_labels = np.array(NU_labels_subset)

# %%
# Combine urban and non-urban images and labels - now we have equal numbers of urban and non-urban elements.
subset_images = np.concatenate((non_urban_images, urban_images), axis = 0)
subset_labels = np.concatenate((non_urban_labels, urban_labels), axis = 0)

# %%
# Visualize Images - note, some categories are not visible due to channels selected
import matplotlib.pyplot as plt

random_index = np.random.choice(subset_labels.shape[0],1)
category_image = subset_images[random_index].reshape(64,64,3)
categories = ["Not Urban", "Urban"] # currently 1 = urban and 0 = not urban
plt.imshow(category_image)
plt.title(f"Category is: {categories[subset_labels[random_index][0]]}")
# Out:
# Text(0.5, 1.0, 'Category is: Not Urban')

# %%
import sklearn

# split test and train data
from sklearn.model_selection import train_test_split 

# using the train test split function
(X_train, X_test, Y_train, Y_test) = train_test_split(subset_images, subset_labels,
                                                      stratify = subset_labels,
                                                        random_state=104, 
                                                        test_size=0.5, 
                                                        shuffle=True)

# %%
# data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=180
    )

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_augmented = train_datagen.flow(
    x = X_train,
    y = Y_train,
    batch_size=100)

test_augmented = test_datagen.flow(
    x = X_test,
    y = Y_test,
    batch_size=100)

# %%
# Plot an example of an augmented image
for i in train_augmented:
  plt.imshow(i[0][12])
  break
# Out:
# [86]

# %% [markdown]
# # Model 1 - Self-Made CNN

# %%
input_shape = (images.shape[1], images.shape[2], images.shape[3])
num_classes = 2

handmade_cnn = Sequential()
handmade_cnn.add(Conv2D(32, kernel_size=(3, 3), # Conv2D layer - apply 32 convolutions with a 3x3 kernel
                 activation='relu',
                 input_shape=input_shape))
handmade_cnn.add(MaxPooling2D(pool_size=(2, 2))) # Max Pooling 2D layer
handmade_cnn.add(Dropout(0.25)) # drop out
handmade_cnn.add(Flatten()) # flatten before putting into dense network
handmade_cnn.add(Dense(1, activation='sigmoid')) # dense layer 

# comment out summary for space
#handmade_cnn.summary()
plot_model(handmade_cnn, show_shapes=True, show_layer_names=True)

# %%
# compile model
handmade_cnn.compile(
    loss='binary_crossentropy',
    optimizer = "adam",
              metrics=['accuracy'])

history_handmade_cnn = handmade_cnn.fit(train_augmented, # training data
                    batch_size=100,
                    epochs=100,
                    verbose=1,
                    validation_data= (test_augmented))  # testing data
# Out:
# Epoch 1/100
# 2/2 [==============================] - 9s 383ms/step - loss: 1.5275 - accuracy: 0.4649 - val_loss: 0.7838 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.8544 - accuracy: 0.4474 - val_loss: 0.9227 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.8443 - accuracy: 0.5000 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7133 - accuracy: 0.4912 - val_loss: 0.7211 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.7254 - accuracy: 0.5000 - val_loss: 0.6978 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7046 - accuracy: 0.5000 - val_loss: 0.6545 - val_accuracy: 0.7368
# Epoch 7/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.6745 - accuracy: 0.5526 - val_loss: 0.6439 - val_accuracy: 0.5702
# Epoch 8/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6645 - accuracy: 0.5614 - val_loss: 0.6193 - val_accuracy: 0.7456
# Epoch 9/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.6430 - accuracy: 0.6754 - val_loss: 0.6491 - val_accuracy: 0.5526
# Epoch 10/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6543 - accuracy: 0.5439 - val_loss: 0.6353 - val_accuracy: 0.5789
# Epoch 11/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6351 - accuracy: 0.6228 - val_loss: 0.6000 - val_accuracy: 0.7193
# Epoch 12/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.6106 - accuracy: 0.7193 - val_loss: 0.5939 - val_accuracy: 0.7193
# Epoch 13/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6089 - accuracy: 0.7281 - val_loss: 0.5870 - val_accuracy: 0.7368
# Epoch 14/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5986 - accuracy: 0.7281 - val_loss: 0.5776 - val_accuracy: 0.7281
# Epoch 15/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6016 - accuracy: 0.7018 - val_loss: 0.5749 - val_accuracy: 0.7281
# Epoch 16/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5793 - accuracy: 0.7105 - val_loss: 0.6335 - val_accuracy: 0.6404
# Epoch 17/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6403 - accuracy: 0.5877 - val_loss: 0.6288 - val_accuracy: 0.6667
# Epoch 18/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.5816 - accuracy: 0.7281 - val_loss: 0.5473 - val_accuracy: 0.7281
# Epoch 19/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5748 - accuracy: 0.7105 - val_loss: 0.5552 - val_accuracy: 0.7193
# Epoch 20/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6046 - accuracy: 0.6930 - val_loss: 0.5425 - val_accuracy: 0.7368
# Epoch 21/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.5746 - accuracy: 0.7193 - val_loss: 0.6072 - val_accuracy: 0.7105
# Epoch 22/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5780 - accuracy: 0.7105 - val_loss: 0.5465 - val_accuracy: 0.7281
# Epoch 23/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5529 - accuracy: 0.7193 - val_loss: 0.5349 - val_accuracy: 0.7368
# Epoch 24/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5860 - accuracy: 0.7368 - val_loss: 0.5293 - val_accuracy: 0.7368
# Epoch 25/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5738 - accuracy: 0.7193 - val_loss: 0.5786 - val_accuracy: 0.7456
# Epoch 26/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5737 - accuracy: 0.6930 - val_loss: 0.5813 - val_accuracy: 0.7456
# Epoch 27/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5736 - accuracy: 0.7281 - val_loss: 0.5383 - val_accuracy: 0.7281
# Epoch 28/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5501 - accuracy: 0.7018 - val_loss: 0.5278 - val_accuracy: 0.7281
# Epoch 29/100
# 2/2 [==============================] - 0s 225ms/step - loss: 0.5823 - accuracy: 0.7018 - val_loss: 0.5307 - val_accuracy: 0.7368
# Epoch 30/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5874 - accuracy: 0.7193 - val_loss: 0.5256 - val_accuracy: 0.7193
# Epoch 31/100
# 2/2 [==============================] - 0s 268ms/step - loss: 0.5518 - accuracy: 0.6842 - val_loss: 0.5655 - val_accuracy: 0.7544
# Epoch 32/100
# 2/2 [==============================] - 0s 229ms/step - loss: 0.5495 - accuracy: 0.6930 - val_loss: 0.5449 - val_accuracy: 0.7368
# Epoch 33/100
# 2/2 [==============================] - 0s 284ms/step - loss: 0.5693 - accuracy: 0.6930 - val_loss: 0.5200 - val_accuracy: 0.7193
# Epoch 34/100
# 2/2 [==============================] - 0s 268ms/step - loss: 0.5635 - accuracy: 0.7281 - val_loss: 0.5312 - val_accuracy: 0.7105
# Epoch 35/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5484 - accuracy: 0.7193 - val_loss: 0.5603 - val_accuracy: 0.7544
# Epoch 36/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.5616 - accuracy: 0.7193 - val_loss: 0.5664 - val_accuracy: 0.7544
# Epoch 37/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5549 - accuracy: 0.7193 - val_loss: 0.5486 - val_accuracy: 0.7632
# Epoch 38/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5523 - accuracy: 0.7018 - val_loss: 0.5455 - val_accuracy: 0.7544
# Epoch 39/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5489 - accuracy: 0.7281 - val_loss: 0.5512 - val_accuracy: 0.7632
# Epoch 40/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5435 - accuracy: 0.7105 - val_loss: 0.5209 - val_accuracy: 0.7281
# Epoch 41/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5653 - accuracy: 0.7368 - val_loss: 0.5180 - val_accuracy: 0.7193
# Epoch 42/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5778 - accuracy: 0.7193 - val_loss: 0.5161 - val_accuracy: 0.7368
# Epoch 43/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.5530 - accuracy: 0.7281 - val_loss: 0.5375 - val_accuracy: 0.7281
# Epoch 44/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5531 - accuracy: 0.6930 - val_loss: 0.5919 - val_accuracy: 0.7456
# Epoch 45/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.5570 - accuracy: 0.7105 - val_loss: 0.5397 - val_accuracy: 0.7368
# Epoch 46/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5512 - accuracy: 0.6842 - val_loss: 0.5224 - val_accuracy: 0.7193
# Epoch 47/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5481 - accuracy: 0.7193 - val_loss: 0.5760 - val_accuracy: 0.7544
# Epoch 48/100
# 2/2 [==============================] - 0s 96ms/step - loss: 0.5690 - accuracy: 0.7105 - val_loss: 0.6148 - val_accuracy: 0.7368
# Epoch 49/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5766 - accuracy: 0.7105 - val_loss: 0.5362 - val_accuracy: 0.7368
# Epoch 50/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5631 - accuracy: 0.7281 - val_loss: 0.5192 - val_accuracy: 0.7281
# Epoch 51/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5639 - accuracy: 0.7193 - val_loss: 0.5472 - val_accuracy: 0.7544
# Epoch 52/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5474 - accuracy: 0.6842 - val_loss: 0.5933 - val_accuracy: 0.7456
# Epoch 53/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5665 - accuracy: 0.7193 - val_loss: 0.5460 - val_accuracy: 0.7544
# Epoch 54/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5485 - accuracy: 0.6842 - val_loss: 0.5355 - val_accuracy: 0.7368
# Epoch 55/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.5567 - accuracy: 0.7018 - val_loss: 0.5269 - val_accuracy: 0.7193
# Epoch 56/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5456 - accuracy: 0.7018 - val_loss: 0.5317 - val_accuracy: 0.7193
# Epoch 57/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5476 - accuracy: 0.7281 - val_loss: 0.5262 - val_accuracy: 0.7281
# Epoch 58/100
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5457 - accuracy: 0.7105 - val_loss: 0.5368 - val_accuracy: 0.7193
# Epoch 59/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5419 - accuracy: 0.6930 - val_loss: 0.5539 - val_accuracy: 0.7632
# Epoch 60/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.5712 - accuracy: 0.7193 - val_loss: 0.6009 - val_accuracy: 0.7456
# Epoch 61/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5623 - accuracy: 0.7105 - val_loss: 0.5331 - val_accuracy: 0.7193
# Epoch 62/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.5417 - accuracy: 0.7193 - val_loss: 0.5170 - val_accuracy: 0.7281
# Epoch 63/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5406 - accuracy: 0.7105 - val_loss: 0.5413 - val_accuracy: 0.7368
# Epoch 64/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5490 - accuracy: 0.7018 - val_loss: 0.5389 - val_accuracy: 0.7368
# Epoch 65/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.5469 - accuracy: 0.7193 - val_loss: 0.5354 - val_accuracy: 0.7193
# Epoch 66/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5450 - accuracy: 0.7281 - val_loss: 0.5218 - val_accuracy: 0.7281
# Epoch 67/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.5461 - accuracy: 0.7193 - val_loss: 0.5321 - val_accuracy: 0.7281
# Epoch 68/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5448 - accuracy: 0.6930 - val_loss: 0.5582 - val_accuracy: 0.7544
# Epoch 69/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5493 - accuracy: 0.7018 - val_loss: 0.5510 - val_accuracy: 0.7544
# Epoch 70/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5463 - accuracy: 0.7018 - val_loss: 0.5239 - val_accuracy: 0.7281
# Epoch 71/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.5466 - accuracy: 0.7281 - val_loss: 0.5170 - val_accuracy: 0.7281
# Epoch 72/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.5841 - accuracy: 0.7105 - val_loss: 0.5144 - val_accuracy: 0.7456
# Epoch 73/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.6013 - accuracy: 0.7193 - val_loss: 0.5120 - val_accuracy: 0.7456
# Epoch 74/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5851 - accuracy: 0.7368 - val_loss: 0.5548 - val_accuracy: 0.7632
# Epoch 75/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.5652 - accuracy: 0.7193 - val_loss: 0.6352 - val_accuracy: 0.7368
# Epoch 76/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5809 - accuracy: 0.7105 - val_loss: 0.5756 - val_accuracy: 0.7544
# Epoch 77/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5487 - accuracy: 0.7018 - val_loss: 0.5317 - val_accuracy: 0.7368
# Epoch 78/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.5458 - accuracy: 0.7018 - val_loss: 0.5174 - val_accuracy: 0.7456
# Epoch 79/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5540 - accuracy: 0.7281 - val_loss: 0.5349 - val_accuracy: 0.7456
# Epoch 80/100
# 2/2 [==============================] - 0s 219ms/step - loss: 0.5557 - accuracy: 0.7193 - val_loss: 0.6240 - val_accuracy: 0.7368
# Epoch 81/100
# 2/2 [==============================] - 0s 231ms/step - loss: 0.5604 - accuracy: 0.7281 - val_loss: 0.5702 - val_accuracy: 0.7544
# Epoch 82/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5464 - accuracy: 0.7368 - val_loss: 0.5223 - val_accuracy: 0.7193
# Epoch 83/100
# 2/2 [==============================] - 0s 244ms/step - loss: 0.5485 - accuracy: 0.7281 - val_loss: 0.5119 - val_accuracy: 0.7281
# Epoch 84/100
# 2/2 [==============================] - 0s 268ms/step - loss: 0.5551 - accuracy: 0.7018 - val_loss: 0.5838 - val_accuracy: 0.7544
# Epoch 85/100
# 2/2 [==============================] - 0s 256ms/step - loss: 0.5642 - accuracy: 0.7193 - val_loss: 0.5756 - val_accuracy: 0.7544
# Epoch 86/100
# 2/2 [==============================] - 0s 222ms/step - loss: 0.5496 - accuracy: 0.7193 - val_loss: 0.5206 - val_accuracy: 0.7193
# Epoch 87/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5420 - accuracy: 0.7193 - val_loss: 0.5073 - val_accuracy: 0.7456
# Epoch 88/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5534 - accuracy: 0.7456 - val_loss: 0.5111 - val_accuracy: 0.7281
# Epoch 89/100
# 2/2 [==============================] - 0s 276ms/step - loss: 0.5519 - accuracy: 0.6930 - val_loss: 0.5890 - val_accuracy: 0.7456
# Epoch 90/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.5506 - accuracy: 0.7105 - val_loss: 0.5369 - val_accuracy: 0.7456
# Epoch 91/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.5472 - accuracy: 0.6930 - val_loss: 0.5224 - val_accuracy: 0.7193
# Epoch 92/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.5414 - accuracy: 0.7281 - val_loss: 0.5153 - val_accuracy: 0.7193
# Epoch 93/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.5439 - accuracy: 0.7105 - val_loss: 0.5461 - val_accuracy: 0.7544
# Epoch 94/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.5409 - accuracy: 0.7018 - val_loss: 0.5346 - val_accuracy: 0.7368
# Epoch 95/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.5449 - accuracy: 0.7105 - val_loss: 0.5568 - val_accuracy: 0.7632
# Epoch 96/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5374 - accuracy: 0.7281 - val_loss: 0.5480 - val_accuracy: 0.7544
# Epoch 97/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5408 - accuracy: 0.7018 - val_loss: 0.5378 - val_accuracy: 0.7281
# Epoch 98/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5428 - accuracy: 0.7105 - val_loss: 0.5265 - val_accuracy: 0.7281
# Epoch 99/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.5416 - accuracy: 0.7018 - val_loss: 0.5257 - val_accuracy: 0.7281
# Epoch 100/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.5422 - accuracy: 0.7456 - val_loss: 0.6037 - val_accuracy: 0.7456

# %%
handmade_cnn_score = handmade_cnn.evaluate(X_test, Y_test, verbose=0) #Y_test_cat
accuracy_handmade_cnn = handmade_cnn_score[1]
print('Handmade Model accuracy:', round(accuracy_handmade_cnn, 3) * 100, "%")
# Out:
# Handmade Model accuracy: 75.4 %

# %%
plot_accuracy_and_loss(history_handmade_cnn)
# Out:
# ([<matplotlib.lines.Line2D at 0x7f4f602143d0>],
#  [<matplotlib.lines.Line2D at 0x7f4f60215540>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4f60254d90>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7f4f60102d40>],
#  [<matplotlib.lines.Line2D at 0x7f4f60103040>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4f602dbf70>,
#  None)

# %% [markdown]
# ## Assess Accuracy

# %%
plot_cm(handmade_cnn, X_test, "Confusion Matrix, Handmade Model")
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7f4f60133340>,
#  Text(0.5, 1.0, 'Confusion Matrix, Handmade Model'))

# %%
plot_roc_curve(handmade_cnn, X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# ([<matplotlib.lines.Line2D at 0x7f4eec3b7d60>],
#  [<matplotlib.lines.Line2D at 0x7f4eec3e8070>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7f4eec3a3250>)

# %%
plot_false_positives(handmade_cnn, X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')

# %% [markdown]
# # VGG-16

# %%
# load vgg model
from keras.applications.vgg16 import VGG16

# load the model
vgg16 = VGG16(weights='imagenet', include_top = False, input_shape=input_shape) # set VGG to trainable, set VGG to take images shaped as 64*64*3
#vgg16.summary()

# preprocess data for VGG16
from keras.applications.vgg16 import preprocess_input

X_train_vgg = preprocess_input(X_train) # normalize training data
X_test_vgg = preprocess_input(X_test) # normalize test data

# this is the augmentation configuration we will use for training
train_datagen_vgg = ImageDataGenerator(
    rotation_range=180
    )
    

# this is the augmentation configuration we will use for testing:
# (none, since vgg preprocessing already rescales images)
test_datagen_vgg = ImageDataGenerator()

# Augment data
train_augmented_vgg = train_datagen_vgg.flow(
    x = X_train_vgg,
    y = Y_train,
    batch_size=100)

test_augmented_vgg = test_datagen_vgg.flow(
    x = X_test_vgg,
    y = Y_test,
    batch_size=100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
# Add last layers for our images
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
drop_out_layer = layers.Dropout(0.2)
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(1, activation='sigmoid')

# set model architecture
vgg16_model = models.Sequential([
    vgg16,
    flatten_layer,
    dense_layer_1,
    drop_out_layer,
    dense_layer_2,
    prediction_layer
])

plot_model(vgg16_model, show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.callbacks import EarlyStopping

vgg16_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)


es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# commenting out so it doesn't run accidentally - takes forever to run
history_vgg16 = vgg16_model.fit(train_augmented_vgg,
            epochs=100,
            validation_split=0.2,
            batch_size=100,
            callbacks=[es],
            validation_data=test_augmented_vgg)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 12s 4s/step - loss: 16.7109 - accuracy: 0.5175 - val_loss: 166.4242 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 253ms/step - loss: 21.1078 - accuracy: 0.5088 - val_loss: 0.8812 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 247ms/step - loss: 1.4587 - accuracy: 0.5000 - val_loss: 0.8518 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 251ms/step - loss: 0.8806 - accuracy: 0.4298 - val_loss: 0.8038 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9043 - accuracy: 0.4386 - val_loss: 0.6915 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.7186 - accuracy: 0.4912 - val_loss: 0.8068 - val_accuracy: 0.5000

# %%
vgg16_model_score = vgg16_model.evaluate(X_test_vgg, Y_test, verbose=0)
accuracy_vgg16_model = vgg16_model_score[1]
print('VGG-16 Test accuracy:', round(accuracy_vgg16_model, 3) * 100, "%")
# Out:
# VGG-16 Test accuracy: 50.0 %

# %%
plot_accuracy_and_loss(history_vgg16)
# Out:
# ([<matplotlib.lines.Line2D at 0x7f4ed9bba560>],
#  [<matplotlib.lines.Line2D at 0x7f4ed9bba830>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4ed9b9fe20>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7f4ed9a02860>],
#  [<matplotlib.lines.Line2D at 0x7f4ed9a02b30>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4ed9b6fd30>,
#  None)

# %%
plot_cm(vgg16_model, X_test_vgg, "Confusion Matrix: VGG16")
# Out:
# 4/4 [==============================] - 0s 11ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7f4ed9a03a60>,
#  Text(0.5, 1.0, 'Confusion Matrix: VGG16'))

# %%
plot_roc_curve(vgg16_model, X_test_vgg)
# Out:
# 4/4 [==============================] - 0s 11ms/step
# ([<matplotlib.lines.Line2D at 0x7f4eecb7b9a0>],
#  [<matplotlib.lines.Line2D at 0x7f4eecba7160>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7f4eecb79f90>)

# %%
plot_false_positives(vgg16_model, X_test_vgg) # may not work if predicted no positives
# Out:
# 4/4 [==============================] - 0s 16ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')

# %% [markdown]
# # EfficientNet V2
# https://arxiv.org/abs/2104.00298

# %%
# load model
from keras.applications.efficientnet_v2 import EfficientNetV2S

# load the model
eff_net = EfficientNetV2S(weights='imagenet', include_top = False, input_shape=input_shape) # set to trainable, set to take images shaped as 64*64*3
#eff_net.summary()

# preprocess data for EfficientNet
from keras.applications.efficientnet_v2 import preprocess_input

X_train_EN = preprocess_input(X_train) # normalize training data
X_test_EN = preprocess_input(X_test) # normalize test data


# this is the augmentation configuration we will use for training
train_datagen_EN = ImageDataGenerator(
    rotation_range=180
    )
    

# this is the augmentation configuration we will use for testing:
# (none, since EN preprocessing already rescales images)
test_datagen_EN = ImageDataGenerator()


# Augment data
train_augmented_EN = train_datagen_EN.flow(
    x = X_train_EN,
     y = Y_train,
     batch_size=100)

test_augmented_EN = test_datagen_EN.flow(
    x = X_test_EN,
    y = Y_test,
    batch_size=100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 5s 0us/step

# %%
# Add last layers for our images

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
drop_out_layer = layers.Dropout(0.2)
dense_layer_2 = layers.Dense(20, activation='relu')
prediction_layer = layers.Dense(1, activation='sigmoid')

# set model architecture
efficient_net_model = models.Sequential([
    eff_net,
    flatten_layer,
    dense_layer_1,
    drop_out_layer,
    dense_layer_2,
    prediction_layer
])

plot_model(efficient_net_model, show_shapes=True, show_layer_names=True)

# %%
# Compile
efficient_net_model.compile(
    optimizer='adam',
    #loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# Train
history_efficient_net = efficient_net_model.fit(train_augmented_EN, #X_train_EN,
            #Y_train_cat,
            epochs=100,
            validation_split=0.2,
            batch_size=100,
            callbacks=[es],
            validation_data=test_augmented_EN)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 98s 6s/step - loss: 0.7071 - accuracy: 0.5351 - val_loss: 0.6675 - val_accuracy: 0.5877
# Epoch 2/100
# 2/2 [==============================] - 0s 264ms/step - loss: 0.5799 - accuracy: 0.6754 - val_loss: 0.6353 - val_accuracy: 0.5877
# Epoch 3/100
# 2/2 [==============================] - 1s 415ms/step - loss: 0.5491 - accuracy: 0.6754 - val_loss: 0.6159 - val_accuracy: 0.6140
# Epoch 4/100
# 2/2 [==============================] - 0s 202ms/step - loss: 0.4449 - accuracy: 0.8070 - val_loss: 0.6480 - val_accuracy: 0.5526
# Epoch 5/100
# 2/2 [==============================] - 0s 194ms/step - loss: 0.4385 - accuracy: 0.8333 - val_loss: 0.6485 - val_accuracy: 0.5789
# Epoch 6/100
# 2/2 [==============================] - 0s 192ms/step - loss: 0.4437 - accuracy: 0.8070 - val_loss: 0.6241 - val_accuracy: 0.6140
# Epoch 7/100
# 2/2 [==============================] - 1s 425ms/step - loss: 0.4248 - accuracy: 0.7632 - val_loss: 0.5984 - val_accuracy: 0.6404
# Epoch 8/100
# 2/2 [==============================] - 0s 274ms/step - loss: 0.3539 - accuracy: 0.8684 - val_loss: 0.5804 - val_accuracy: 0.6228
# Epoch 9/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.4207 - accuracy: 0.8246 - val_loss: 0.5540 - val_accuracy: 0.6404
# Epoch 10/100
# 2/2 [==============================] - 1s 411ms/step - loss: 0.3211 - accuracy: 0.8684 - val_loss: 0.5469 - val_accuracy: 0.6930
# Epoch 11/100
# 2/2 [==============================] - 1s 409ms/step - loss: 0.3541 - accuracy: 0.8509 - val_loss: 0.5558 - val_accuracy: 0.7281
# Epoch 12/100
# 2/2 [==============================] - 0s 197ms/step - loss: 0.3732 - accuracy: 0.8070 - val_loss: 0.5281 - val_accuracy: 0.7281
# Epoch 13/100
# 2/2 [==============================] - 0s 265ms/step - loss: 0.2575 - accuracy: 0.8947 - val_loss: 0.5683 - val_accuracy: 0.7105
# Epoch 14/100
# 2/2 [==============================] - 0s 261ms/step - loss: 0.3581 - accuracy: 0.8333 - val_loss: 0.6583 - val_accuracy: 0.7105
# Epoch 15/100
# 2/2 [==============================] - 0s 273ms/step - loss: 0.4826 - accuracy: 0.7982 - val_loss: 0.8170 - val_accuracy: 0.7281
# Epoch 16/100
# 2/2 [==============================] - 1s 619ms/step - loss: 0.3924 - accuracy: 0.8333 - val_loss: 0.8729 - val_accuracy: 0.7193

# %%
efficient_net_model_score = efficient_net_model.evaluate(X_test_EN, Y_test, verbose=0)
accuracy_eff_net = efficient_net_model_score[1]
print('EfficientNetV2 Test accuracy:', round(accuracy_eff_net, 3) * 100, "%")
# Out:
# EfficientNetV2 Test accuracy: 72.8 %

# %%
plot_accuracy_and_loss(history_efficient_net)
# Out:
# ([<matplotlib.lines.Line2D at 0x7f4ea8bc39a0>],
#  [<matplotlib.lines.Line2D at 0x7f4ea8bc3c70>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4e4867f5b0>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7f4ea8a598d0>],
#  [<matplotlib.lines.Line2D at 0x7f4ea8a59ba0>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7f4ea8a27760>,
#  None)

# %%
plot_cm(efficient_net_model, X_test_EN, "Confusion Matrix, EfficicentNetV2")
# Out:
# 4/4 [==============================] - 3s 37ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7f4ea8aa3910>,
#  Text(0.5, 1.0, 'Confusion Matrix, EfficicentNetV2'))

# %%
plot_roc_curve(efficient_net_model, X_test_EN)
# Out:
# 4/4 [==============================] - 0s 27ms/step
# ([<matplotlib.lines.Line2D at 0x7f4e9176a4a0>],
#  [<matplotlib.lines.Line2D at 0x7f4e9176a770>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7f4ec6104790>)

# %%
plot_false_positives(efficient_net_model, X_test_EN)
# Out:
# 4/4 [==============================] - 0s 24ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')
