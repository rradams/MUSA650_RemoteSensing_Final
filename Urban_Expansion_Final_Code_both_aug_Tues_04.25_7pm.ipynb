# %% [markdown]
# <a href="https://colab.research.google.com/github/rradams/MUSA650_RemoteSensing_Final/blob/main/Urban_Expansion_Final_Code_both_aug_Tues_04.25_7pm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MUSA 650: Remote Sensing - Final Project**
#
# Identifying Urban Expansion in Cirebon, Indonesia
#
# Rebekah Adams and Tiffany Tran

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import math
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import RMSprop # optimizer
import keras
import tensorflow as tf
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# # Set up functions

# %%
# import pandas as pd

# # Create dataframe of prediction accuracies

# def prediction_by_category(model, test_set):
#   categories_dict = {1:"Urban", 0:"Not_Urban"}
#   predict_x=model.predict(test_set) # predictions with probabilities for each class

#   # find accurate predictions
#   label_count = np.unique(Y_test, return_counts = True)[1] # number of labels of test set
#   classes_x=np.round(predict_x) # the class with the highest-predicted probabilities, i.e. the best guess
#   y_test_pred = [categories_dict[x] for x in classes_x] # convert the predictions to the category names
#   y_test_true = [categories_dict[x] for x in Y_test] # convert the true labels to the category names

#   # Create dataframe
#   pred_df = pd.DataFrame({'y_true': y_test_true, 'y_pred': y_test_pred})
#   pred_df['accurate_preds'] = pred_df.y_true == pred_df.y_pred
#   pred_df = pred_df.groupby(['y_true']).sum().reset_index()
#   pred_df['label_count'] = label_count
#   pred_df['class_acc'] = pred_df.accurate_preds / pred_df.label_count
#   pred_df['overall_acc'] = sum(pred_df.accurate_preds) / sum(pred_df.label_count)

#   return(pred_df)

# %%
# Create function to plot confusion matrix
def plot_cm(model, test_data, title):
  predict_x = np.round(model.predict(test_data))
  #classes_x = np.argmax(predict_x, axis=1)
  cm = confusion_matrix(Y_test, predict_x)
  disp = ConfusionMatrixDisplay(confusion_matrix= cm,
                                display_labels=categories)
  
  return(
      disp.plot(),
      disp.ax_.set_title(f"{title}")
  )

# %%
# Create function to plot ROC curve - how to make less angular?
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(model, test_set):
  predict_x=model.predict(test_set) # predictions with probabilities for each class
  #classes_x=np.argmax(predict_x,axis=1) # the class with the highest-predicted probabilities, i.e. the best guess

  # Compute fpr, tpr, thresholds and roc auc
  fpr, tpr, thresholds = roc_curve(Y_test, predict_x)
  roc_auc = auc(fpr, tpr)

  # Plot ROC curve
  return(
      plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc),
      plt.plot([0, 1], [0, 1], 'k--'),  # random predictions curve
      plt.xlim([0.0, 1.0]),
      plt.ylim([0.0, 1.0]),
      plt.xlabel('False Positive Rate or (1 - Specifity)'),
      plt.ylabel('True Positive Rate or (Sensitivity)'),
      plt.title('Receiver Operating Characteristic'),
      plt.legend(loc="lower right")
  )

# %%
  # Plot images of False Positives - images that were predicted as Urban, but were actually Not Urban
  # This could help us identify areas of urban expansion

from mpl_toolkits.axes_grid1 import ImageGrid

def plot_false_positives(model, test_set):

    predict_x = np.round(model.predict(test_set))
    #classes_x = np.argmax(predict_x,axis=1)
    wrong_classifications = predict_x - Y_test # predicted classes - actual classes # classes_x
    #wrong_classifications_index = np.where(wrong_classifications != 0) # index of where predictions were wrong
    wrong_classifications_index = np.array(np.where(wrong_classifications != 0)) # index of where predictions were wrong
    wrong_classifications_index_reshaped = wrong_classifications_index.reshape(1, wrong_classifications_index.shape[1]*wrong_classifications_index.shape[0])
    wrong_predictions = predict_x[wrong_classifications_index_reshaped] # use index to find wrong predictions # classes_x
    #wrong_predictions = predict_x[wrong_classifications_index] # use index to find wrong predictions # classes_x
    wrong_y_true = Y_test[wrong_classifications_index] # use index to find correct labels of wrong predictions
    wrong_x_true = X_test[wrong_classifications_index] # use index to find pixels of incorrectly-predicted images

    # Identify False Positive - true Not Urban, predicted as Urban
    FP_index = np.where(wrong_y_true == 0) # find labels Not Urban areas, i.e. the false positives (Non-Urban labelled as 0)
    FP_labels = wrong_y_true[FP_index]
    FP_images = wrong_x_true[FP_index]

    # Select random sample of images from false positive results
    index_list = []

    for i in range(0,4):
      random_index = np.random.choice(FP_labels.shape[0])
      index_list.append(random_index)

    # Use random index to select four random images
    image_1 = FP_images[index_list[0]].reshape(64,64,3)
    image_2 = FP_images[index_list[1]].reshape(64,64,3)
    image_3 = FP_images[index_list[2]].reshape(64,64,3)
    image_4 = FP_images[index_list[3]].reshape(64,64,3)

    # Plot
    fig = plt.figure() #figsize=(4., 4.))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                    nrows_ncols=(2, 2),  # creates 2x2 grid of axes
                    axes_pad=0.1,  # pad between axes in inch.
                    )

    for ax, im in zip(grid, [image_1, image_2, image_3, image_4]):
        # Iterating over the grid returns the Axes.
        ax.imshow(im)

    return(grid.axes_all[1].set_title("Examples of False Positive Classifications - Predicted as Urban, but are officially not urban"))

# %%
# Function to plot accuracy and loss for each model
def plot_accuracy_and_loss(model_history):
  return(
    plt.plot(model_history.history['accuracy']),
    plt.plot(model_history.history['val_accuracy']),
    plt.title('model accuracy'),
    plt.ylabel('accuracy'),
    plt.xlabel('epoch'),
    plt.legend(['train', 'test'], loc='upper left'),
    plt.show(),

    plt.plot(model_history.history['loss']),
    plt.plot(model_history.history['val_loss']),
    plt.title('model loss'),
    plt.ylabel('loss'),
    plt.xlabel('epoch'),
    plt.legend(['train', 'test'], loc='upper left'),
    plt.show(),
  )

# %% [markdown]
# # Import images

# %%
# pip install imagecodecs

# %%
# import images

import os
import skimage
from skimage import io
import numpy as np
from glob import glob
from pathlib import Path
#import imagecodecs

raw_labels =[]
raw_images = []
raw_label_names = []
here = Path(os.getcwd())

for idx, directory in enumerate(sorted((here / "drive/MyDrive/MUSA650_RemoteSensing_Final/data/").glob("*"))):  # keep this line for running on colab
#for idx, directory in enumerate((here / "./data/cirebon").glob("*")):  # Keep this line for running locally
    for img_path in directory.glob("*.jpg"):
        raw_labels.append(idx)
        raw_label_names.append(directory)
        raw_images.append(io.imread(img_path))
        
# convert to numpy arrays
images = np.array(raw_images)
images = images[:, :64, :64, :3] # trim extra pixel and alpha channel
labels = np.array(raw_labels)
label_names = np.array(raw_label_names)

# %%
label_names
# Out:
# array([PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/not_urban'),
#        ...,
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban'),
#        PosixPath('/content/drive/MyDrive/MUSA650_RemoteSensing_Final/data/urban')],
#       dtype=object)

# %%
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
# Switch 0s to 1s and 1s to 0s (so urban = 1, not_urban = 0) - test only
# labels_test = labels

# # flip 1s to 0s and 0s to 1s
# array_flip = np.logical_not(labels_test).astype(int)

# # print old vs. new array
# print(labels_test)
# print(array_flip)

# %%
# # Switch 0s to 1s and 1s to 0s (so urban = 1, not_urban = 0)
# # flip 1s to 0s and 0s to 1s
# labels_flip = np.logical_not(labels).astype(int)

# # print old vs. new array
# print(labels)
# print(labels_flip)

# %%
# Confrim the range of values in the dataset - yes, they are between 0 and 255
print("Max pixel value is: ", images.max())
print("Min pixel value is: ", images.min())
# Out:
# Max pixel value is:  255
# Min pixel value is:  0

# %%
urban_labels_index = np.where(labels == 1)
urban_labels = labels[urban_labels_index]
urban_images = images[urban_labels_index]

# %%
# Draw out just the non-urban images
non_urban_labels_index = np.where(labels == 0)
non_urban_labels = labels[non_urban_labels_index]
non_urban_images = images[non_urban_labels_index]

# Generate a random selection of non-urban images - the same number as urban images.
NU_labels_subset = []
NU_images_subset = []

for i in range(0, urban_labels.shape[0]):
  random_index_for_subset = np.random.choice(non_urban_labels.shape[0])
  subset_label = non_urban_labels[random_index_for_subset]
  subset_image = non_urban_images[random_index_for_subset]
  NU_labels_subset.append(subset_label)
  NU_images_subset.append(subset_image)

# Convert to numpy arrays
non_urban_images = np.array(NU_images_subset)
non_urban_labels = np.array(NU_labels_subset)

# %%
# Combine urban and non-urban images and labels - now we have equal numbers of urban and non-urban elements.
subset_images = np.concatenate((non_urban_images, urban_images), axis = 0)
subset_labels = np.concatenate((non_urban_labels, urban_labels), axis = 0)

# %%
# Visualize Images - note, some categories are not visible due to channels selected
import matplotlib.pyplot as plt

random_index = np.random.choice(subset_labels.shape[0],1)
category_image = subset_images[random_index].reshape(64,64,3)
categories = ["Not Urban", "Urban"] # currently 1 = urban and 0 = not urban
plt.imshow(category_image)
plt.title(f"Category is: {categories[subset_labels[random_index][0]]}")
# Out:
# Text(0.5, 1.0, 'Category is: Urban')

# %%
import sklearn

# split test and train data
from sklearn.model_selection import train_test_split 

# using the train test split function
(X_train, X_test, Y_train, Y_test) = train_test_split(subset_images, subset_labels,
                                                      stratify = subset_labels,
                                                        random_state=104, 
                                                        test_size=0.5, 
                                                        shuffle=True)

# %%
# Data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=180
    #fill_mode='reflect'
    #shear_range=0.2,
    #zoom_range=0.2,
    #horizontal_flip=True
    )
    

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_augmented = train_datagen.flow(
    x = X_train,
    y = Y_train,
    batch_size=100)

test_augmented = test_datagen.flow(
    x = X_test,
    y = Y_test,
    batch_size=100)

# %%
for i in train_augmented:
  #random_index = np.random.choice(subset_labels.shape[0],1)
  # category_image = i[random_index].reshape(64,64,3)
  # categories = ["Not Urban", "Urban"] # currently 1 = urban and 0 = not urban
  # plt.imshow(category_image)
  # plt.title(f"Category is: {categories[subset_labels[random_index][0]]}")
  plt.imshow(i[0][10])
  #print(len(i))
  break

# %% [markdown]
# # Data Augmentation

# %%
# pip install protobuf==3.20.0

# %%
# # import libraries
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from matplotlib.pyplot import imread, imshow, subplots, show

# %%
# # function to plot augmented images

# def plot(data_generator):
#     """
#     Plots 6 images generated by an object of the ImageDataGenerator class.
#     """
#     data_generator.fit(urban_images_aug)
#     image_iterator = data_generator.flow(urban_images_aug)
    
#     # plot images from iterator
#     fig, rows = subplots(nrows=1, ncols=6, figsize=(18,18))
#     for row in rows:
#         row.imshow(image_iterator.next()[0].astype('int'))
#         row.axis('off')
#     show()

# %%
# # read in test image
# image_test = imread('./data/cirebon/urban/urban_103.jpg')

# # create dataset with one test image
# images_test = image_test.reshape((1, image_test.shape[0], image_test.shape[1], image_test.shape[2]))

# imshow(images_test[0])
# show()

# %%
# apply transformations to test image
# data_generator = ImageDataGenerator(rotation_range=180, fill_mode='reflect')
# # data_generator = ImageDataGenerator(rotation_range=30, fill_mode='reflect')
# plot(data_generator)

# %%
# # apply brightness
# data_generator = ImageDataGenerator(brightness_range=(0.7, 1.3))
# plot(data_generator)

# # let's not use this method

# %%
# # apply zoom
# data_generator = ImageDataGenerator(zoom_range=[0.2, 2.5])
# plot(data_generator)

# # let's not use this method

# %%
# from matplotlib.pyplot import imread, imshow, subplots, show

# # create dataset with all urban images (batch_size, height, width, channels)
# urban_images_aug = urban_images.reshape((urban_images.shape[0], 64, 64, 3))

# imshow(urban_images_aug[33]) # show one image
# show()

# %%
# # check dataset shape; should be (114, 64, 64, 3)
# urban_images_aug.shape

# %%
# # apply transformations to urban images
# data_generator = ImageDataGenerator(rotation_range=180, fill_mode='reflect')

# plot(data_generator)

# %%
# # generate augmented images
# train_generator = data_generator.flow(urban_images_aug, batch_size=32)

# %%
# train model on augmented images
# model.fit_generator(train_generator, epochs=10, steps_per_epoch=len(x_train) / 32)

# %% [markdown]
# # Model 1 - Self-Made CNN

# %%
input_shape = (images.shape[1], images.shape[2], images.shape[3])
num_classes = 2

handmade_cnn = Sequential()
handmade_cnn.add(Conv2D(32, kernel_size=(3, 3), # Conv2D layer - apply 32 convolutions with a 3x3 kernel
                 activation='relu',
                 input_shape=input_shape))
handmade_cnn.add(MaxPooling2D(pool_size=(2, 2))) # Max Pooling 2D layer
handmade_cnn.add(Dropout(0.25)) # drop out
handmade_cnn.add(Flatten()) # flatten before putting into dense network
handmade_cnn.add(Dense(1, activation='sigmoid')) # dense layer # 'softmax' activation='sigmoid' num_classes

# comment out summary for space
#handmade_cnn.summary()
#plot_model(handmade_cnn, show_shapes=True, show_layer_names=True)

# %%
# compile model
handmade_cnn.compile(
    #loss='categorical_crossentropy',
    loss='binary_crossentropy',
    optimizer = "Adam",
              #optimizer=RMSprop(),
              metrics=['accuracy'])

# convert class vectors to binary class matrices
# Y_train_cat = keras.utils.np_utils.to_categorical(Y_train, num_classes)
# Y_test_cat = keras.utils.np_utils.to_categorical(Y_test, num_classes)

# train
# history_handmade_cnn = handmade_cnn.fit(X_train, Y_train_cat, # training data
#                     #batch_size=2000,
#                     epochs=100,
#                     verbose=1,
#                     validation_data= (X_test, Y_test_cat)) # testing data


history_handmade_cnn = handmade_cnn.fit_generator(train_augmented, #Y_train_cat, #X_train, Y_train_cat, # training data
                    #batch_size=2000,
                    epochs=100,
                    verbose=1,
                    validation_data= (test_augmented)) #Y_test_cat)) #(X_test, Y_test_cat)) # testing data
# Out:
# <ipython-input-36-e743178395be>:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_handmade_cnn = handmade_cnn.fit_generator(train_augmented, #Y_train_cat, #X_train, Y_train_cat, # training data
# Epoch 1/100
# 2/2 [==============================] - 12s 916ms/step - loss: 1.2900 - accuracy: 0.4912 - val_loss: 0.8289 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 294ms/step - loss: 0.6810 - accuracy: 0.5702 - val_loss: 0.7864 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 239ms/step - loss: 0.8865 - accuracy: 0.5000 - val_loss: 0.7985 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.7915 - accuracy: 0.5000 - val_loss: 0.6338 - val_accuracy: 0.6228
# Epoch 5/100
# 2/2 [==============================] - 0s 244ms/step - loss: 0.6434 - accuracy: 0.6316 - val_loss: 0.6067 - val_accuracy: 0.7895
# Epoch 6/100
# 2/2 [==============================] - 0s 361ms/step - loss: 0.6180 - accuracy: 0.7368 - val_loss: 0.5741 - val_accuracy: 0.7895
# Epoch 7/100
# 2/2 [==============================] - 0s 312ms/step - loss: 0.5921 - accuracy: 0.7193 - val_loss: 0.5508 - val_accuracy: 0.7982
# Epoch 8/100
# 2/2 [==============================] - 1s 208ms/step - loss: 0.5816 - accuracy: 0.7105 - val_loss: 0.5398 - val_accuracy: 0.7719
# Epoch 9/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5700 - accuracy: 0.6667 - val_loss: 0.5163 - val_accuracy: 0.7982
# Epoch 10/100
# 2/2 [==============================] - 0s 314ms/step - loss: 0.5475 - accuracy: 0.7018 - val_loss: 0.5091 - val_accuracy: 0.7719
# Epoch 11/100
# 2/2 [==============================] - 0s 262ms/step - loss: 0.5493 - accuracy: 0.7018 - val_loss: 0.5059 - val_accuracy: 0.7632
# Epoch 12/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5380 - accuracy: 0.7632 - val_loss: 0.4918 - val_accuracy: 0.7719
# Epoch 13/100
# 2/2 [==============================] - 1s 184ms/step - loss: 0.5464 - accuracy: 0.7281 - val_loss: 0.4852 - val_accuracy: 0.7982
# Epoch 14/100
# 2/2 [==============================] - 0s 426ms/step - loss: 0.5480 - accuracy: 0.7281 - val_loss: 0.5022 - val_accuracy: 0.7719
# Epoch 15/100
# 2/2 [==============================] - 1s 284ms/step - loss: 0.5389 - accuracy: 0.6842 - val_loss: 0.5869 - val_accuracy: 0.7105
# Epoch 16/100
# 2/2 [==============================] - 1s 200ms/step - loss: 0.5764 - accuracy: 0.6404 - val_loss: 0.5929 - val_accuracy: 0.7105
# Epoch 17/100
# 2/2 [==============================] - 1s 441ms/step - loss: 0.5528 - accuracy: 0.6667 - val_loss: 0.5005 - val_accuracy: 0.7719
# Epoch 18/100
# 2/2 [==============================] - 1s 425ms/step - loss: 0.5484 - accuracy: 0.7807 - val_loss: 0.5107 - val_accuracy: 0.7632
# Epoch 19/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.5722 - accuracy: 0.7456 - val_loss: 0.5006 - val_accuracy: 0.7895
# Epoch 20/100
# 2/2 [==============================] - 0s 318ms/step - loss: 0.5349 - accuracy: 0.7456 - val_loss: 0.5170 - val_accuracy: 0.7632
# Epoch 21/100
# 2/2 [==============================] - 0s 290ms/step - loss: 0.5562 - accuracy: 0.6316 - val_loss: 0.5774 - val_accuracy: 0.7018
# Epoch 22/100
# 2/2 [==============================] - 1s 498ms/step - loss: 0.5850 - accuracy: 0.6404 - val_loss: 0.5766 - val_accuracy: 0.7105
# Epoch 23/100
# 2/2 [==============================] - 1s 140ms/step - loss: 0.5616 - accuracy: 0.6404 - val_loss: 0.5020 - val_accuracy: 0.7807
# Epoch 24/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.5244 - accuracy: 0.7544 - val_loss: 0.4848 - val_accuracy: 0.7982
# Epoch 25/100
# 2/2 [==============================] - 0s 328ms/step - loss: 0.5412 - accuracy: 0.7807 - val_loss: 0.4774 - val_accuracy: 0.8070
# Epoch 26/100
# 2/2 [==============================] - 0s 280ms/step - loss: 0.5208 - accuracy: 0.7807 - val_loss: 0.4794 - val_accuracy: 0.7719
# Epoch 27/100
# 2/2 [==============================] - 1s 91ms/step - loss: 0.5095 - accuracy: 0.7632 - val_loss: 0.5627 - val_accuracy: 0.7368
# Epoch 28/100
# 2/2 [==============================] - 0s 302ms/step - loss: 0.6002 - accuracy: 0.6140 - val_loss: 0.6274 - val_accuracy: 0.6754
# Epoch 29/100
# 2/2 [==============================] - 0s 318ms/step - loss: 0.5427 - accuracy: 0.6930 - val_loss: 0.4770 - val_accuracy: 0.7719
# Epoch 30/100
# 2/2 [==============================] - 0s 202ms/step - loss: 0.5819 - accuracy: 0.7544 - val_loss: 0.5178 - val_accuracy: 0.7456
# Epoch 31/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6291 - accuracy: 0.7105 - val_loss: 0.4850 - val_accuracy: 0.7719
# Epoch 32/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.5214 - accuracy: 0.7807 - val_loss: 0.4902 - val_accuracy: 0.7632
# Epoch 33/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5106 - accuracy: 0.7105 - val_loss: 0.5970 - val_accuracy: 0.7018
# Epoch 34/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.5642 - accuracy: 0.6228 - val_loss: 0.5336 - val_accuracy: 0.7632
# Epoch 35/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.5119 - accuracy: 0.7018 - val_loss: 0.4898 - val_accuracy: 0.7719
# Epoch 36/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5276 - accuracy: 0.7368 - val_loss: 0.4992 - val_accuracy: 0.7719
# Epoch 37/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.5700 - accuracy: 0.7368 - val_loss: 0.5065 - val_accuracy: 0.7632
# Epoch 38/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.5449 - accuracy: 0.7719 - val_loss: 0.4959 - val_accuracy: 0.7719
# Epoch 39/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5301 - accuracy: 0.7368 - val_loss: 0.5219 - val_accuracy: 0.7807
# Epoch 40/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5227 - accuracy: 0.6842 - val_loss: 0.5382 - val_accuracy: 0.7719
# Epoch 41/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5215 - accuracy: 0.6842 - val_loss: 0.5074 - val_accuracy: 0.7632
# Epoch 42/100
# 2/2 [==============================] - 0s 283ms/step - loss: 0.5057 - accuracy: 0.7105 - val_loss: 0.4875 - val_accuracy: 0.7719
# Epoch 43/100
# 2/2 [==============================] - 0s 271ms/step - loss: 0.4981 - accuracy: 0.7456 - val_loss: 0.4692 - val_accuracy: 0.7632
# Epoch 44/100
# 2/2 [==============================] - 0s 239ms/step - loss: 0.5080 - accuracy: 0.7544 - val_loss: 0.4696 - val_accuracy: 0.7719
# Epoch 45/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.4997 - accuracy: 0.7456 - val_loss: 0.5223 - val_accuracy: 0.7632
# Epoch 46/100
# 2/2 [==============================] - 1s 149ms/step - loss: 0.5169 - accuracy: 0.7018 - val_loss: 0.6073 - val_accuracy: 0.7193
# Epoch 47/100
# 2/2 [==============================] - 0s 273ms/step - loss: 0.5381 - accuracy: 0.6667 - val_loss: 0.4973 - val_accuracy: 0.7632
# Epoch 48/100
# 2/2 [==============================] - 0s 269ms/step - loss: 0.4967 - accuracy: 0.7632 - val_loss: 0.4635 - val_accuracy: 0.7807
# Epoch 49/100
# 2/2 [==============================] - 0s 309ms/step - loss: 0.5335 - accuracy: 0.7807 - val_loss: 0.4674 - val_accuracy: 0.7807
# Epoch 50/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5288 - accuracy: 0.7895 - val_loss: 0.4678 - val_accuracy: 0.7807
# Epoch 51/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5072 - accuracy: 0.7895 - val_loss: 0.4908 - val_accuracy: 0.7632
# Epoch 52/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5032 - accuracy: 0.7105 - val_loss: 0.5385 - val_accuracy: 0.7719
# Epoch 53/100
# 2/2 [==============================] - 0s 235ms/step - loss: 0.5130 - accuracy: 0.6930 - val_loss: 0.5555 - val_accuracy: 0.7719
# Epoch 54/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5226 - accuracy: 0.6930 - val_loss: 0.5150 - val_accuracy: 0.7632
# Epoch 55/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5061 - accuracy: 0.7105 - val_loss: 0.4860 - val_accuracy: 0.7632
# Epoch 56/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.4907 - accuracy: 0.7368 - val_loss: 0.4693 - val_accuracy: 0.7807
# Epoch 57/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5094 - accuracy: 0.7982 - val_loss: 0.4674 - val_accuracy: 0.7982
# Epoch 58/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.5124 - accuracy: 0.7895 - val_loss: 0.4863 - val_accuracy: 0.7632
# Epoch 59/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.5008 - accuracy: 0.7018 - val_loss: 0.5585 - val_accuracy: 0.7632
# Epoch 60/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5184 - accuracy: 0.6930 - val_loss: 0.5854 - val_accuracy: 0.7368
# Epoch 61/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.5361 - accuracy: 0.7018 - val_loss: 0.5530 - val_accuracy: 0.7719
# Epoch 62/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5121 - accuracy: 0.7105 - val_loss: 0.4870 - val_accuracy: 0.7632
# Epoch 63/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.4961 - accuracy: 0.7632 - val_loss: 0.4707 - val_accuracy: 0.7719
# Epoch 64/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.5056 - accuracy: 0.7895 - val_loss: 0.4601 - val_accuracy: 0.8070
# Epoch 65/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.5118 - accuracy: 0.7895 - val_loss: 0.4646 - val_accuracy: 0.7807
# Epoch 66/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4953 - accuracy: 0.7719 - val_loss: 0.4940 - val_accuracy: 0.7719
# Epoch 67/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.4874 - accuracy: 0.7193 - val_loss: 0.5039 - val_accuracy: 0.7632
# Epoch 68/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.4963 - accuracy: 0.7018 - val_loss: 0.4637 - val_accuracy: 0.7807
# Epoch 69/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.5043 - accuracy: 0.7895 - val_loss: 0.4554 - val_accuracy: 0.7982
# Epoch 70/100
# 2/2 [==============================] - 1s 498ms/step - loss: 0.5501 - accuracy: 0.7632 - val_loss: 0.4680 - val_accuracy: 0.7719
# Epoch 71/100
# 2/2 [==============================] - 1s 150ms/step - loss: 0.5588 - accuracy: 0.7544 - val_loss: 0.4614 - val_accuracy: 0.7807
# Epoch 72/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.5255 - accuracy: 0.7719 - val_loss: 0.4686 - val_accuracy: 0.7632
# Epoch 73/100
# 2/2 [==============================] - 0s 403ms/step - loss: 0.4900 - accuracy: 0.7632 - val_loss: 0.4965 - val_accuracy: 0.7719
# Epoch 74/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4801 - accuracy: 0.7281 - val_loss: 0.5453 - val_accuracy: 0.7719
# Epoch 75/100
# 2/2 [==============================] - 0s 428ms/step - loss: 0.5203 - accuracy: 0.6842 - val_loss: 0.5574 - val_accuracy: 0.7719
# Epoch 76/100
# 2/2 [==============================] - 0s 311ms/step - loss: 0.4983 - accuracy: 0.6930 - val_loss: 0.4769 - val_accuracy: 0.7719
# Epoch 77/100
# 2/2 [==============================] - 1s 625ms/step - loss: 0.5083 - accuracy: 0.7895 - val_loss: 0.4587 - val_accuracy: 0.7895
# Epoch 78/100
# 2/2 [==============================] - 1s 564ms/step - loss: 0.5127 - accuracy: 0.7895 - val_loss: 0.4545 - val_accuracy: 0.8070
# Epoch 79/100
# 2/2 [==============================] - 1s 159ms/step - loss: 0.4881 - accuracy: 0.7895 - val_loss: 0.5026 - val_accuracy: 0.7632
# Epoch 80/100
# 2/2 [==============================] - 1s 516ms/step - loss: 0.4968 - accuracy: 0.7018 - val_loss: 0.5830 - val_accuracy: 0.7281
# Epoch 81/100
# 2/2 [==============================] - 1s 221ms/step - loss: 0.5235 - accuracy: 0.6667 - val_loss: 0.5164 - val_accuracy: 0.7719
# Epoch 82/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.4900 - accuracy: 0.7105 - val_loss: 0.4601 - val_accuracy: 0.7982
# Epoch 83/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.4935 - accuracy: 0.8070 - val_loss: 0.4665 - val_accuracy: 0.7895
# Epoch 84/100
# 2/2 [==============================] - 0s 295ms/step - loss: 0.5368 - accuracy: 0.7544 - val_loss: 0.4611 - val_accuracy: 0.7982
# Epoch 85/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5195 - accuracy: 0.7807 - val_loss: 0.4672 - val_accuracy: 0.7632
# Epoch 86/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.4938 - accuracy: 0.7895 - val_loss: 0.5272 - val_accuracy: 0.7807
# Epoch 87/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.4930 - accuracy: 0.7018 - val_loss: 0.5933 - val_accuracy: 0.7281
# Epoch 88/100
# 2/2 [==============================] - 0s 312ms/step - loss: 0.5386 - accuracy: 0.7018 - val_loss: 0.5875 - val_accuracy: 0.7281
# Epoch 89/100
# 2/2 [==============================] - 1s 561ms/step - loss: 0.4979 - accuracy: 0.6842 - val_loss: 0.4780 - val_accuracy: 0.7544
# Epoch 90/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.4865 - accuracy: 0.7105 - val_loss: 0.4488 - val_accuracy: 0.8158
# Epoch 91/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.5040 - accuracy: 0.7982 - val_loss: 0.4499 - val_accuracy: 0.8070
# Epoch 92/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4973 - accuracy: 0.7982 - val_loss: 0.4710 - val_accuracy: 0.7544
# Epoch 93/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.4768 - accuracy: 0.7368 - val_loss: 0.5351 - val_accuracy: 0.7807
# Epoch 94/100
# 2/2 [==============================] - 0s 196ms/step - loss: 0.4903 - accuracy: 0.7193 - val_loss: 0.5025 - val_accuracy: 0.7719
# Epoch 95/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4827 - accuracy: 0.7193 - val_loss: 0.4687 - val_accuracy: 0.7632
# Epoch 96/100
# 2/2 [==============================] - 0s 291ms/step - loss: 0.4822 - accuracy: 0.7807 - val_loss: 0.4647 - val_accuracy: 0.7807
# Epoch 97/100
# 2/2 [==============================] - 0s 222ms/step - loss: 0.4862 - accuracy: 0.7807 - val_loss: 0.4533 - val_accuracy: 0.8070
# Epoch 98/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4822 - accuracy: 0.7982 - val_loss: 0.4627 - val_accuracy: 0.7895
# Epoch 99/100
# 2/2 [==============================] - 0s 322ms/step - loss: 0.4738 - accuracy: 0.7807 - val_loss: 0.4911 - val_accuracy: 0.7719
# Epoch 100/100
# 2/2 [==============================] - 0s 427ms/step - loss: 0.4744 - accuracy: 0.7281 - val_loss: 0.4959 - val_accuracy: 0.7632

# %%
handmade_cnn_score = handmade_cnn.evaluate(X_test, Y_test, verbose=0) #Y_test_cat
accuracy_handmade_cnn = handmade_cnn_score[1]
print('Handmade Model accuracy:', round(accuracy_handmade_cnn, 3) * 100, "%")
# Out:
# Handmade Model accuracy: 78.9 %

# %%
#def plot_cm(model, test_data, title):
predict_x = np.round(handmade_cnn.predict(X_test))
#classes_x = np.argmax(predict_x, axis=1)
cm = confusion_matrix(Y_test, predict_x)
disp = ConfusionMatrixDisplay(confusion_matrix= cm,
                                 display_labels=categories)
  
# #   #return(
disp.plot(),
# disp.ax_.set_title(f"{title}")
#   #)
#print(predict_x)
#print(Y_test)
# Out:
# 4/4 [==============================] - 0s 8ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7fbb5cdbe0d0>,)

# %%
plot_accuracy_and_loss(history_handmade_cnn)
# Out:
# ([<matplotlib.lines.Line2D at 0x7fbb5cc12fa0>],
#  [<matplotlib.lines.Line2D at 0x7fbb5cc202b0>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fbb5cc78820>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7fbb5cb414f0>],
#  [<matplotlib.lines.Line2D at 0x7fbb5cb417c0>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fbb5cb8feb0>,
#  None)

# %% [markdown]
# ## Assess Accuracy

# %%
plot_cm(handmade_cnn, X_test, "Confusion Matrix, Handmade Model")
# Out:
# 4/4 [==============================] - 0s 5ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7fbb5cb141f0>,
#  Text(0.5, 1.0, 'Confusion Matrix, Handmade Model'))

# %%
plot_roc_curve(handmade_cnn, X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# ([<matplotlib.lines.Line2D at 0x7fbb5c4aadc0>],
#  [<matplotlib.lines.Line2D at 0x7fbb5c4aad00>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7fbb5c4d69a0>)

# %%
plot_false_positives(handmade_cnn, X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')

# %% [markdown]
# # VGG-16

# %%
# load vgg model
from keras.applications.vgg16 import VGG16

# load the model
vgg16 = VGG16(weights='imagenet', include_top = False, input_shape=input_shape) # set VGG to trainable, set VGG to take images shaped as 64*64*3
#vgg16.summary()

# preprocess data for VGG16
from keras.applications.vgg16 import preprocess_input

X_train_vgg = preprocess_input(X_train) # normalize training data
X_test_vgg = preprocess_input(X_test) # normalize test data

# this is the augmentation configuration we will use for training
train_datagen_vgg = ImageDataGenerator(
    #rescale=1. / 255,
    rotation_range=180
    #fill_mode='reflect'
    #shear_range=0.2,
    #zoom_range=0.2,
    #horizontal_flip=True
    )
    

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen_vgg = ImageDataGenerator() #rescale=1. / 255)


# Augment data
train_augmented_vgg = train_datagen_vgg.flow(
    x = X_train_vgg,
    y = Y_train,
    batch_size=100)

test_augmented_vgg = test_datagen_vgg.flow(
    x = X_test_vgg,
    y = Y_test,
    batch_size=100)

# %%
# Add last layers for our images
from tensorflow.keras import layers, models

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
drop_out_layer = layers.Dropout(0.2)
dense_layer_2 = layers.Dense(20, activation='relu')
#prediction_layer = layers.Dense(num_classes, activation='softmax')
prediction_layer = layers.Dense(1, activation='sigmoid')

# set model architecture
vgg16_model = models.Sequential([
    vgg16,
    flatten_layer,
    dense_layer_1,
    drop_out_layer,
    dense_layer_2,
    prediction_layer
])

# %%
from tensorflow.keras.callbacks import EarlyStopping

vgg16_model.compile(
    optimizer='adam',
    #loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)


es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# commenting out so it doesn't run accidentally - takes forever to run
history_vgg16 = vgg16_model.fit(train_augmented_vgg, #X_train_vgg,
            #Y_train_cat,
            epochs=100,
            validation_split=0.2,
            batch_size=100,
            callbacks=[es],
            validation_data=test_augmented_vgg)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 7s 488ms/step - loss: 3.3930 - accuracy: 0.5263 - val_loss: 65.6123 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 119ms/step - loss: 62.0905 - accuracy: 0.4912 - val_loss: 0.9192 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.9271 - accuracy: 0.4649 - val_loss: 0.6975 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.7299 - accuracy: 0.5175 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 0s 264ms/step - loss: 0.7898 - accuracy: 0.4737 - val_loss: 0.7037 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 0s 188ms/step - loss: 0.7023 - accuracy: 0.5000 - val_loss: 0.6912 - val_accuracy: 0.5000

# %%
vgg16_model_score = vgg16_model.evaluate(X_test_vgg, Y_test, verbose=0)
accuracy_vgg16_model = vgg16_model_score[1]
print('VGG-16 Test accuracy:', round(accuracy_vgg16_model, 3) * 100, "%")
# Out:
# VGG-16 Test accuracy: 50.0 %

# %%
plot_accuracy_and_loss(history_vgg16)
# Out:
# ([<matplotlib.lines.Line2D at 0x7fb8f100c9a0>],
#  [<matplotlib.lines.Line2D at 0x7fb8f100cd30>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fb8f1027bb0>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7fb8f37b51f0>],
#  [<matplotlib.lines.Line2D at 0x7fb8f37b54c0>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fb8f378c910>,
#  None)

# %%
plot_cm(vgg16_model, X_test_vgg, "Confusion Matrix: VGG16")
# Out:
# 4/4 [==============================] - 0s 20ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7fb8f377b340>,
#  Text(0.5, 1.0, 'Confusion Matrix: VGG16'))

# %%
plot_roc_curve(vgg16_model, X_test_vgg)
# Out:
# 4/4 [==============================] - 0s 20ms/step
# ([<matplotlib.lines.Line2D at 0x7fb8f8afb550>],
#  [<matplotlib.lines.Line2D at 0x7fb8f8afb820>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7fb8f8acea60>)

# %%
plot_false_positives(vgg16_model, X_test_vgg) # does not work because predicted no positives
# Out:
# 4/4 [==============================] - 0s 19ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')

# %% [markdown]
# # EfficientNet V2
# https://arxiv.org/abs/2104.00298

# %%
# load model
from keras.applications.efficientnet_v2 import EfficientNetV2S

# load the model
eff_net = EfficientNetV2S(weights='imagenet', include_top = False, input_shape=input_shape) # set to trainable, set to take images shaped as 64*64*3
#eff_net.summary()

# preprocess data for EfficientNet
from keras.applications.efficientnet_v2 import preprocess_input

X_train_EN = preprocess_input(X_train) # normalize training data
X_test_EN = preprocess_input(X_test) # normalize test data


# this is the augmentation configuration we will use for training
train_datagen_EN = ImageDataGenerator(
    #rescale=1. / 255,
    rotation_range=180
    #fill_mode='reflect'
    #shear_range=0.2,
    #zoom_range=0.2,
    #horizontal_flip=True
    )
    

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen_EN = ImageDataGenerator() #rescale=1. / 255)


# Augment data
# train_augmented_EN = train_datagen.flow(
#     x = X_train_EN,
#     y = Y_train,
#     batch_size=100)

train_augmented_EN = train_datagen_EN.flow(
    x = X_train_EN,
     y = Y_train,
     batch_size=100)

# test_augmented_EN = test_datagen.flow(
#     x = X_test_EN,
#     y = Y_test,
#     batch_size=100)

test_augmented_EN = test_datagen_EN.flow(
    x = X_test_EN,
    y = Y_test,
    batch_size=100)

# %%
# Add last layers for our images

flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(50, activation='relu')
drop_out_layer = layers.Dropout(0.2)
dense_layer_2 = layers.Dense(20, activation='relu')
#prediction_layer = layers.Dense(num_classes, activation='softmax')
prediction_layer = layers.Dense(1, activation='sigmoid')

# set model architecture
efficient_net_model = models.Sequential([
    eff_net,
    flatten_layer,
    dense_layer_1,
    drop_out_layer,
    dense_layer_2,
    prediction_layer
])

# %%
# Compile
efficient_net_model.compile(
    optimizer='adam',
    #loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# Train
history_efficient_net = efficient_net_model.fit(train_augmented_EN, #X_train_EN,
            #Y_train_cat,
            epochs=100,
            validation_split=0.2,
            batch_size=100,
            callbacks=[es],
            validation_data=test_augmented_EN)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 99s 4s/step - loss: 0.7355 - accuracy: 0.5088 - val_loss: 0.6765 - val_accuracy: 0.5614
# Epoch 2/100
# 2/2 [==============================] - 1s 443ms/step - loss: 0.6801 - accuracy: 0.6228 - val_loss: 0.6578 - val_accuracy: 0.6316
# Epoch 3/100
# 2/2 [==============================] - 0s 205ms/step - loss: 0.5485 - accuracy: 0.7193 - val_loss: 0.6435 - val_accuracy: 0.5614
# Epoch 4/100
# 2/2 [==============================] - 0s 285ms/step - loss: 0.5638 - accuracy: 0.7105 - val_loss: 0.6602 - val_accuracy: 0.5702
# Epoch 5/100
# 2/2 [==============================] - 0s 204ms/step - loss: 0.5635 - accuracy: 0.6842 - val_loss: 0.5978 - val_accuracy: 0.6316
# Epoch 6/100
# 2/2 [==============================] - 1s 510ms/step - loss: 0.5910 - accuracy: 0.7193 - val_loss: 0.5043 - val_accuracy: 0.7632
# Epoch 7/100
# 2/2 [==============================] - 1s 430ms/step - loss: 0.4734 - accuracy: 0.7982 - val_loss: 0.4874 - val_accuracy: 0.7632
# Epoch 8/100
# 2/2 [==============================] - 1s 357ms/step - loss: 0.4475 - accuracy: 0.7456 - val_loss: 0.5597 - val_accuracy: 0.7456
# Epoch 9/100
# 2/2 [==============================] - 1s 284ms/step - loss: 0.4954 - accuracy: 0.7456 - val_loss: 0.6286 - val_accuracy: 0.7193
# Epoch 10/100
# 2/2 [==============================] - 1s 272ms/step - loss: 0.3923 - accuracy: 0.8070 - val_loss: 0.5965 - val_accuracy: 0.7105
# Epoch 11/100
# 2/2 [==============================] - 1s 570ms/step - loss: 0.3840 - accuracy: 0.8246 - val_loss: 0.5613 - val_accuracy: 0.6930

# %%
efficient_net_model_score = efficient_net_model.evaluate(X_test_EN, Y_test, verbose=0)
accuracy_eff_net = efficient_net_model_score[1]
print('EfficientNetV2 Test accuracy:', round(accuracy_eff_net, 3) * 100, "%")
# Out:
# EfficientNetV2 Test accuracy: 76.3 %

# %%
plot_accuracy_and_loss(history_efficient_net)
# Out:
# ([<matplotlib.lines.Line2D at 0x7fba04a3ddc0>],
#  [<matplotlib.lines.Line2D at 0x7fba049da0d0>],
#  Text(0.5, 1.0, 'model accuracy'),
#  Text(24.000000000000007, 0.5, 'accuracy'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fb908609ac0>,
#  None,
#  [<matplotlib.lines.Line2D at 0x7fba049c1ac0>],
#  [<matplotlib.lines.Line2D at 0x7fba049c1d90>],
#  Text(0.5, 1.0, 'model loss'),
#  Text(24.000000000000007, 0.5, 'loss'),
#  Text(0.5, 24.0, 'epoch'),
#  <matplotlib.legend.Legend at 0x7fba049af1c0>,
#  None)

# %%
plot_cm(efficient_net_model, X_test_EN, "Confusion Matrix, EfficicentNetV2")
# Out:
# 4/4 [==============================] - 3s 34ms/step
# (<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x7fb903eceee0>,
#  Text(0.5, 1.0, 'Confusion Matrix, EfficicentNetV2'))

# %%
plot_roc_curve(efficient_net_model, X_test_EN)
# Out:
# 4/4 [==============================] - 0s 37ms/step
# ([<matplotlib.lines.Line2D at 0x7fb903caf4f0>],
#  [<matplotlib.lines.Line2D at 0x7fb903caf7c0>],
#  (0.0, 1.0),
#  (0.0, 1.0),
#  Text(0.5, 0, 'False Positive Rate or (1 - Specifity)'),
#  Text(0, 0.5, 'True Positive Rate or (Sensitivity)'),
#  Text(0.5, 1.0, 'Receiver Operating Characteristic'),
#  <matplotlib.legend.Legend at 0x7fb903c90070>)

# %%
plot_false_positives(efficient_net_model, X_test_EN)
# Out:
# 4/4 [==============================] - 0s 34ms/step
# Text(0.5, 1.0, 'Examples of False Positive Classifications - Predicted as Urban, but are officially not urban')
